# %%
import pandas as pd

var1=pd.Series([5,8,3,5,3])
var1
# Out:
# 0    5
# 1    8
# 2    3
# 3    5
# 4    3
# dtype: int64

# %%
# var1={"Marks":[18,45,78],"RollNum":[101,102,103]}

# var2=pd.Series(var1)
# var2

prices = pd.Series([99.5, 120.75, 89.99])
prices
# Out:
# 0     99.50
# 1    120.75
# 2     89.99
# dtype: float64
